# %%
# %load_ext autoreload
# %autoreload 2
 
from generate_layout import simulation

# %%
box_dim = (8, 10)

# %%
M_module_coordinates = [(0, 0), (0, 5), (3, 5), (1, 3), (3, 0)] # start from (0, 0)
M_modules = simulation(box_dim, M_module_coordinates, max_iter_per_simulation=500, N=50, plot_name='M')
# Out:
# Number of modules is bounded by 9
# Simulation 1...
# Layout from 1 simulation can fit in 4 modules
# Simulation 2...
# Layout from 2 simulation can fit in 3 modules
# Simulation 3...
# Layout from 3 simulation can fit in 4 modules
# Simulation 4...
# Layout from 4 simulation can fit in 3 modules
# Simulation 5...
# Layout from 5 simulation can fit in 4 modules
# Simulation 6...
# Layout from 6 simulation can fit in 4 modules
# Simulation 7...
# Layout from 7 simulation can fit in 3 modules
# Simulation 8...
# Layout from 8 simulation can fit in 4 modules
# Simulation 9...
# Layout from 9 simulation can fit in 3 modules
# Simulation 10...
# Layout from 10 simulation can fit in 3 modules
# Simulation 11...
# Layout from 11 simulation can fit in 4 modules
# Simulation 12...
# Layout from 12 simulation can fit in 4 modules
# Simulation 13...
# Layout from 13 simulation can fit in 3 modules
# Simulation 14...
# Layout from 14 simulation can fit in 4 modules
# Simulation 15...
# Layout from 15 simulation can fit in 4 modules
# Simulation 16...
# Layout from 16 simulation can fit in 4 modules
# Simulation 17...
# Layout from 17 simulation can fit in 3 modules
# Simulation 18...
# Layout from 18 simulation can fit in 3 modules
# Simulation 19...
# Layout from 19 simulation can fit in 4 modules
# Simulation 20...
# Layout from 20 simulation can fit in 3 modules
# Simulation 21...
# Layout from 21 simulation can fit in 4 modules
# Simulation 22...
# Layout from 22 simulation can fit in 4 modules
# Simulation 23...
# Layout from 23 simulation can fit in 3 modules
# Simulation 24...
# Layout from 24 simulation can fit in 4 modules
# Simulation 25...
# Layout from 25 simulation can fit in 5 modules
# Simulation 26...
# Layout from 26 simulation can fit in 3 modules
# Simulation 27...
# Layout from 27 simulation can fit in 4 modules
# Simulation 28...
# Layout from 28 simulation can fit in 4 modules
# Simulation 29...
# Layout from 29 simulation can fit in 3 modules
# Simulation 30...
# Layout from 30 simulation can fit in 4 modules
# Simulation 31...
# Layout from 31 simulation can fit in 4 modules
# Simulation 32...
# Layout from 32 simulation can fit in 3 modules
# Simulation 33...
# Layout from 33 simulation can fit in 3 modules
# Simulation 34...
# Layout from 34 simulation can fit in 5 modules
# Simulation 35...
# Layout from 35 simulation can fit in 4 modules
# Simulation 36...
# Layout from 36 simulation can fit in 5 modules
# Simulation 37...
# Layout from 37 simulation can fit in 4 modules
# Simulation 38...
# Layout from 38 simulation can fit in 5 modules
# Simulation 39...
# Layout from 39 simulation can fit in 4 modules
# Simulation 40...
# Layout from 40 simulation can fit in 4 modules
# Simulation 41...
# Layout from 41 simulation can fit in 4 modules
# Simulation 42...
# Layout from 42 simulation can fit in 3 modules
# Simulation 43...
# Layout from 43 simulation can fit in 4 modules
# Simulation 44...
# Layout from 44 simulation can fit in 3 modules
# Simulation 45...
# Layout from 45 simulation can fit in 4 modules
# Simulation 46...
# Layout from 46 simulation can fit in 3 modules
# Simulation 47...
# Layout from 47 simulation can fit in 3 modules
# Simulation 48...
# Layout from 48 simulation can fit in 4 modules
# Simulation 49...
# Layout from 49 simulation can fit in 3 modules
# Simulation 50...
# Layout from 50 simulation can fit in 3 modules
# Simulation 51...
# Layout from 51 simulation can fit in 4 modules
# Simulation 52...
# Layout from 52 simulation can fit in 3 modules
# Simulation 53...
# Layout from 53 simulation can fit in 3 modules
# Simulation 54...
# Layout from 54 simulation can fit in 4 modules
# Simulation 55...
# Layout from 55 simulation can fit in 4 modules
# Simulation 56...
# Layout from 56 simulation can fit in 3 modules
# Simulation 57...
# Layout from 57 simulation can fit in 3 modules
# Simulation 58...
# Layout from 58 simulation can fit in 3 modules
# Simulation 59...
# Layout from 59 simulation can fit in 4 modules
# Simulation 60...
# Layout from 60 simulation can fit in 3 modules
# Simulation 61...
# Layout from 61 simulation can fit in 4 modules
# Simulation 62...
# Layout from 62 simulation can fit in 4 modules
# Simulation 63...
# Layout from 63 simulation can fit in 3 modules
# Simulation 64...
# Layout from 64 simulation can fit in 4 modules
# Simulation 65...
# Layout from 65 simulation can fit in 3 modules
# Simulation 66...
# Layout from 66 simulation can fit in 3 modules
# Simulation 67...
# Layout from 67 simulation can fit in 4 modules
# Simulation 68...
# Layout from 68 simulation can fit in 4 modules
# Simulation 69...
# Layout from 69 simulation can fit in 3 modules
# Simulation 70...
# Layout from 70 simulation can fit in 3 modules
# Simulation 71...
# Layout from 71 simulation can fit in 4 modules
# Simulation 72...
# Layout from 72 simulation can fit in 4 modules
# Simulation 73...
# Layout from 73 simulation can fit in 4 modules
# Simulation 74...
# Layout from 74 simulation can fit in 3 modules
# Simulation 75...
# Layout from 75 simulation can fit in 4 modules
# Simulation 76...
# Layout from 76 simulation can fit in 3 modules
# Simulation 77...
# Layout from 77 simulation can fit in 3 modules
# Simulation 78...
# Layout from 78 simulation can fit in 4 modules
# Simulation 79...
# Layout from 79 simulation can fit in 3 modules
# Simulation 80...
# Layout from 80 simulation can fit in 3 modules
# Simulation 81...
# Layout from 81 simulation can fit in 4 modules
# Simulation 82...
# Layout from 82 simulation can fit in 4 modules
# Simulation 83...
# Layout from 83 simulation can fit in 3 modules
# Simulation 84...
# Layout from 84 simulation can fit in 3 modules
# Simulation 85...
# Layout from 85 simulation can fit in 4 modules
# Simulation 86...
# Layout from 86 simulation can fit in 4 modules
# Simulation 87...
# Layout from 87 simulation can fit in 3 modules
# Simulation 88...
# Layout from 88 simulation can fit in 4 modules
# Simulation 89...
# Layout from 89 simulation can fit in 4 modules
# Simulation 90...
# Layout from 90 simulation can fit in 4 modules
# Simulation 91...
# Layout from 91 simulation can fit in 3 modules
# Simulation 92...
# Layout from 92 simulation can fit in 3 modules
# Simulation 93...
# Layout from 93 simulation can fit in 3 modules
# Simulation 94...
# Layout from 94 simulation can fit in 3 modules
# Simulation 95...
# Layout from 95 simulation can fit in 3 modules
# Simulation 96...
# Layout from 96 simulation can fit in 3 modules
# Simulation 97...
# Layout from 97 simulation can fit in 3 modules
# Simulation 98...
# Layout from 98 simulation can fit in 4 modules
# Simulation 99...
# Layout from 99 simulation can fit in 4 modules
# Simulation 100...
# Layout from 100 simulation can fit in 3 modules
# Best layout can fit in 5 modules

# %%
L_module_coordinates = [(0, 0), (0, 4), (1, 4), (1, 1), (2, 1), (2, 0)]
L_modules = simulation(box_dim, L_module_coordinates, max_iter_per_simulation=5000, N=50, plot_name='L')
# Out:
# Number of modules is bounded by 17
# Simulation 1...
# Layout from 1 simulation can fit in 9 modules
# Simulation 2...
# Layout from 2 simulation can fit in 11 modules
# Simulation 3...
# Layout from 3 simulation can fit in 11 modules
# Simulation 4...
# Layout from 4 simulation can fit in 11 modules
# Simulation 5...
# Layout from 5 simulation can fit in 11 modules
# Simulation 6...
# Layout from 6 simulation can fit in 10 modules
# Simulation 7...
# Layout from 7 simulation can fit in 10 modules
# Simulation 8...
# Layout from 8 simulation can fit in 10 modules
# Simulation 9...
# Layout from 9 simulation can fit in 13 modules
# Simulation 10...
# Layout from 10 simulation can fit in 10 modules
# Simulation 11...
# Layout from 11 simulation can fit in 10 modules
# Simulation 12...
# Layout from 12 simulation can fit in 11 modules
# Simulation 13...
# Layout from 13 simulation can fit in 10 modules
# Simulation 14...
# Layout from 14 simulation can fit in 11 modules
# Simulation 15...
# Layout from 15 simulation can fit in 12 modules
# Simulation 16...
# Layout from 16 simulation can fit in 11 modules
# Simulation 17...
# Layout from 17 simulation can fit in 11 modules
# Simulation 18...
# Layout from 18 simulation can fit in 10 modules
# Simulation 19...
# Layout from 19 simulation can fit in 11 modules
# Simulation 20...
# Layout from 20 simulation can fit in 11 modules
# Simulation 21...
# Layout from 21 simulation can fit in 11 modules
# Simulation 22...
# Layout from 22 simulation can fit in 9 modules
# Simulation 23...
# Layout from 23 simulation can fit in 12 modules
# Simulation 24...
# Layout from 24 simulation can fit in 12 modules
# Simulation 25...
# Layout from 25 simulation can fit in 10 modules
# Simulation 26...
# Layout from 26 simulation can fit in 10 modules
# Simulation 27...
# Layout from 27 simulation can fit in 11 modules
# Simulation 28...
# Layout from 28 simulation can fit in 11 modules
# Simulation 29...
# Layout from 29 simulation can fit in 10 modules
# Simulation 30...
# Layout from 30 simulation can fit in 11 modules
# Simulation 31...
# Layout from 31 simulation can fit in 13 modules
# Simulation 32...
# Layout from 32 simulation can fit in 9 modules
# Simulation 33...
# Layout from 33 simulation can fit in 10 modules
# Simulation 34...
# Layout from 34 simulation can fit in 10 modules
# Simulation 35...
# Layout from 35 simulation can fit in 11 modules
# Simulation 36...
# Layout from 36 simulation can fit in 10 modules
# Simulation 37...
# Layout from 37 simulation can fit in 11 modules
# Simulation 38...
# Layout from 38 simulation can fit in 11 modules
# Simulation 39...
# Layout from 39 simulation can fit in 11 modules
# Simulation 40...
# Layout from 40 simulation can fit in 12 modules
# Simulation 41...
# Layout from 41 simulation can fit in 11 modules
# Simulation 42...
# Layout from 42 simulation can fit in 12 modules
# Simulation 43...
# Layout from 43 simulation can fit in 12 modules
# Simulation 44...
# Layout from 44 simulation can fit in 11 modules
# Simulation 45...
# Layout from 45 simulation can fit in 12 modules
# Simulation 46...
# Layout from 46 simulation can fit in 12 modules
# Simulation 47...
# Layout from 47 simulation can fit in 10 modules
# Simulation 48...
# Layout from 48 simulation can fit in 13 modules
# Simulation 49...
# Layout from 49 simulation can fit in 10 modules
# Simulation 50...
# Layout from 50 simulation can fit in 9 modules
# Best layout can fit in 13 modules
